# %% [markdown]
# #### 딕셔너리란?
# - key 와 value를 한쌍으로 갖는 자료형
# - 불변한 key와 가번/불변적인 value로 맵핑된 순서가 없는 집합
# - 인덱싱, 슬라이싱이 불가능

# %% [markdown]
# #### 딕셔너리 선언

# %%
# 딕셔너리명 = {key:value,key:value,...}
a = {} #빈 딕셔너리
b = {'name':'key'}# 이름정보(문자열)를 담은 딕셔너리
c = {1:'key',2: 23}# 하나의 딕셔너리에는 다양한 자료형을 담을수 있다.
d = {'name':['인성','성현','탁연']}# value값으로 리스트(자료구조)를 담을 수 있다.
# 명확하게 뭔가를 정의하고 싶을 때 딕셔너리를 사용

# %%
print(a)
print(b)
print(c)
print(d)
# Out:
# {}
# {'name': 'key'}
# {1: 'key', 2: 23}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17160\2841538903.py in <module>
#       2 print(b)
#       3 print(c)
# ----> 4 print(name)
#
# NameError: name 'name' is not defined

# %%
print(type(d))
# Out:
# <class 'dict'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#위의 정보를 담는 딕셔너리 선언해보기
dic1 = {'name':"EY", 'age':20, 'phone':"010-1234-5678"}
dic1
# Out:
# {'name': 'EY', 'age': 20, 'phone': '010-1234-5678'}

# %% [markdown]
# ####  딕셔너리 값 추가
# - 새로운 키 : 새로운 값

# %%
# 없는 키값을 부르고 value 값을 대입
dic1['birth'] = '12/05'

# %%
dic1
# Out:
# {'name': 'EY', 'age': 20, 'phone': '010-1234-5678', 'birth': '12/05'}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dic_test={'노래제목':'사건의 지평선'}

# %%
dic_test['가수'] = '윤하'
dic_test['날짜'] = '2022.12.01'
dic_test
# Out:
# {'노래제목': '사건의 지평선', '가수': '윤하', '날짜': '2022.12.01', '효': '창'}

# %% [markdown]
# #### 딕셔너리 값 가져오기 (데이터에 접근하기)

# %%
dic1
#dic1에서 이름 가져오기
dic1['name']
# 폰 번호 가져오기
dic1['phone']
# Out:
# '010-1234-5678'

# %%
# 데이터에 접근할 때 사용하는 함수 :get(키)
dic1['phone']
dic1.get('name')
# 생일 정보 가져오기
dic1.get('birth')
# Out:
# '12/05'

# %% [markdown]
#  - 딕셔너리 접근 방법 비교
#      - 딕셔너리.[키] vs 딕셔너리명.get(키)

# %%
gender =dic1['gender']
gender
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17160\2261457828.py in <module>
# ----> 1 gender =dic1['gender']
#       2 gender
#
# KeyError: 'gender'

# %%
gender = dic1.get('gender')
print(gender)
# Out:
# None

# %%
# 예외처리 try~ except
try: 
    gender = dic1['gender']
    gender
    
except KeyError:
    print('없는 키값입니다')
# Out:
# 없는 키값입니다

# %% [markdown]
# #### 딕셔너리 관련 함수
# - 데이터에 접근하는 방법들

# %%
dic1
# Out:
# {'name': 'EY', 'age': 20, 'phone': '010-1234-5678', 'birth': '12/05'}

# %% [markdown]
# ##### 딕셔너리 키값만 가져오기

# %%
dic1.keys()
# name이라는 키에 접근하고 싶을때(키 값을 인덱싱을 하겠다.)
# 리스트로 형변환하여 키 값들을 인덱싱으로 활용할 수 있음
list(dic1.keys())[0]
# Out:
# dict_keys(['name', 'age', 'phone', 'birth'])

# %% [markdown]
# #### 딕셔너리 value값만 가져오기

# %%
dic1.values()
# Out:
# dict_values(['EY', 20, '010-1234-5678', '12/05'])

# %%
list(dic1.values())[3] #value 값을 리스트로 활용해서 인덱스 활용
# Out:
# '12/05'

# %% [markdown]
# #####  딕셔너리 key.value 모두 가져오기

# %%
# items()
dic1.items()
# Out:
# dict_items([('name', 'EY'), ('age', 20), ('phone', '010-1234-5678'), ('birth', '12/05')])

# %%
list(dic1.items())
# Out:
# ('phone', '010-1234-5678')

# %%
for i in dic1.items(): #튜플 형태로 출력을 해줌
    print(i) #패킹된 형태
# Out:
# ('name', 'EY')
# ('age', 20)
# ('phone', '010-1234-5678')
# ('birth', '12/05')

# %%
for key, value in dic1.items():
    print(key,value) # 언패킹된 형태로 출력
# Out:
# name EY
# age 20
# phone 010-1234-5678
# birth 12/05

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
score_dict = {'이름' : ['선영표', '이주희', '김은영', '서대희', '채수민'],
              'Python' : [90, 100, 85, 90, 80],
              'Java' : [85, 100, 80, 95, 85],
              'html/css' : [75, 70, 90, 80, 90]}

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-4.png](attachment:image-4.png)

# %%
#총합을 구하는 함수 : sum()
# 1. python 과목에 접근해서 결과 가져오기
score = score_dict.get('Python')
py_avg = sum(score[:]) / len(score_dict.get('Python'))
print(py_avg)



# 2. 1번의 합을 사람 수 만큼 나누기

for key, value in score_dict():
    if key == 'Python':
        py_avg = value/len(value)
            print(py_avg)
# Out:
# 89.0

# %% [markdown]
# #### 딕셔너리 값 삭제

# %%
# del 키워드
dic1
# 폰 정보 삭제하기
del dic1['phone'] # 삭제 됨과 동식에 초기화

# %%
dic1
# Out:
# {'name': 'EY', 'age': 20, 'phone': '010-1234-5678'}

# %%
dic2 =dic1
dic2
# Out:
# {'name': 'EY', 'age': 20, 'phone': '010-1234-5678'}

# %%
# 값(데이터)을 모두 삭제할 때

dic2 = dic1
print(dic2)
dic1.clear()
       
print(dic2)
# Out:
# {'name': 'EY', 'age': 20, 'phone': '010-1234-5678'}
# {}

# %%
dic1
# Out:
# {}

# %% [markdown]
# #### 네임스페이스(namespace, 이름공간)
# - 빌트인 네임스페이스 : 기본 내장 함수/내장 예외들의 이름-->최상위 네임스 페이스
# - 전역 네임스페이스 : Gloval, 모듈전체에서 통용될 수 있는 이름
# - 지역 네임스페이스 : local, 함수 내에서만 통용되는 이름
# - 프로그래밍 언어에서 특정한 객체를 이름에 따라 구분할 수 있는 범위

# %%
# 함수정의
num = 0 # 전역변수
def temp():
    num = 1 # 지역변수
    print('함수 안 : ', num)
print('함수 밖 : ', num)    
temp()
# Out:
# 함수 밖 :  0
# 함수 안 :  1

# %%
# 지역변수를 전역변수로 사용하고 싶을 때(인식)
# gloval 키워드 사용
num = 0 # 전역변수
print('함수 밖1 :',num)
def temp():
    global num
    num = 1 # 지역변수
    print('함수 안 : ', num)
print('함수 밖3 : ', num)    

temp() #함수를 호출하면 전역변수로 변경된다.
print('함수 밖2', num)
# Out:
# 함수 밖1 : 0
# 함수 밖3 :  0
# 함수 안 :  1
# 함수 밖2 1

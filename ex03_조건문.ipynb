# %% [markdown]
# ![image.png](attachment:image.png)

# %%
if True:
    print('실행문장  실행')
# Out:
# 실행문장  실행

# %%
# if문에서 조건식이 false였을때는 아무것도 실행하지 않고 끝이 남
if False:
    print('실행문장  실행')

# %%
if True:
    print('실행문장 실행')
print('if문 밖에 있는 실행문장')
# Out:
# 실행문장 실행
# if문 밖에 있는 실행문장

# %%
#if 문 밖에 있는 들여쓰기를 벗어난 실행문장만 false 영향을 받지않고 출력
if False:
    print("실행문장 실행")
print('if문 밖에 있는 실행문장')
# Out:
# if문 밖에 있는 실행문장

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
money = 8000

if money >= 10000 :
    print('택시를 탄다')
# Out:
# 택시를 탄다

# %% [markdown]
# #### if~ else 문

# %%
#조건문 if ~ else 를 활용해서  money가 만원 이상이면 '택시' 만원이하이면 '버스'를 탄다를 출력해보기
money = 8000

if money >= 10000:
    print('택시를 탄다')
else :
    print('버스를 탄다')
# Out:
# 버스를 탄다

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num = int(input("정수 입력 >> "))

if num%3 == 0 and num % 5 == 0:
    print (f'정수{num}는 3과 5의 배수입니다.')
else :
    print (f'정수{num}는 3과 5의 배수가 아닙니다.')
# Out:
# 정수 입력 >> 15
# 정수153과 5의 배수입니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)
# ![image-4.png](attachment:image-4.png)

# %%
cnt_mask = int(input('마스크 개수 입력 >> '))

# 필요한 변수 선언
bundle8,bundle5,temp = 0,0,0

if cnt_mask % 8 == 0:
    print('8개들이 포장지 개수 : ',cnt_mask/8)
else:
    print('8개들이 포장지 개수 : ',cnt_mask/8 
    print('5개들이 포장지 개수 : ' ,round(cnt_mask %8/5)+1)
# Out:
#   File "C:\Users\smhrd\AppData\Local\Temp\ipykernel_11284\1681651573.py", line 6
#     print('5개들이 포장지 개수 : ' ,round(cnt_mask %8/5)+1)
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num1 = int(input('첫 번째 정수 입력 >> '))
num2 = int(input('두 번째 정수 입력 >> '))

if num1 > num2:
    print('첫 번째 정수가 더 큽니다.')
elif num2 > num1:
     print('두 번째 정수가 더 큽니다.')
else:
    print('두 수가 똑같습니다.')
# Out:
# 첫 번째 정수 입력 >> 10
# 두 번째 정수 입력 >> 5
# 첫 번째 정수가 더 큽니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
score = int(input('점수 입력 >> '))
if score<=100 and score>=90:
    print(f'{score}점은 A학점입니다')
elif score<90 and score>=80:
    print(f'{score}점은 B학점입니다')
elif score<80 and score>=70:
    print(f'{score}점은 C학점입니다')
elif score<70 and score>=60:
    print(f'{score}점은 D학점입니다')   
else:
    print(f'{score}점은 F학점입니다')
# Out:
# 점수 입력 >> 15
# 15점은 F학점입니다

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-5.png](attachment:image-5.png)

# %%
print("""
================================================
================---- 자판기 ----================
================================================
== 1.콜라 == 2.사이다 ==  3.물  =======insert===
==--------==----------==--------=======------===
==   600  ==    800   ==  1000  ======= O00원===
=======================================------===
================================================
==++++++++++++++++++++++++++++++++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
==+++++++++++++++              +++++++++++++++==
==+++++++++++++++     SMHRD    +++++++++++++++==
==+++++++++++++++              +++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
==++++++++++++++++++++++++++++++++++++++++++++==
================================================
================================================
  ===                                      ===
  ===                                      ===""")
insert = int(input('금액 넣기 >> '))
menu = int(input('메뉴 선택(번호입력) >> '))

콜라 = 600
사이다 = 800
물 = 1000
if insert >= 콜라:
    if menu == 1:
        if insert >= 콜라:
            거스름돈 = insert - 콜라
            print('1000원 : ',거스름돈//1000,'개','500원 : ',거스름돈%1000//500,'개','100원 : ',거스름돈%1000%500//100,'개')
        else:
            print('금액이 부족합니다.')            
    elif menu == 2:
        if insert >= 사이다:
            거스름돈 = insert - 사이다
            print('1000원 : ',거스름돈//1000,'개','500원 : ',거스름돈%1000//500,'개','100원 : ',거스름돈%1000%500//100,'개')
        else:
            print('금액이 부족합니다.')  
    
    elif menu == 3:
        if insert >= 물:
            거스름돈 = insert - 물
            print('1000원 : ',거스름돈//1000,'개','500원 : ',거스름돈%1000//500,'개','100원 : ',거스름돈%1000%500//100,'개')
        else:
            print('금액이 부족합니다.')  
else:
    print('금액이 부족합니다.')
# Out:
# ...
# ================---- 자판기 ----================
# ...
# == 1.콜라 == 2.사이다 ==  3.물  =======insert===
# ==--------==----------==--------=======------===
# ==   600  ==    800   ==  1000  ======= O00원===
# =======================================------===
# ...
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==+++++++++++++++              +++++++++++++++==
# ==+++++++++++++++     SMHRD    +++++++++++++++==
# ==+++++++++++++++              +++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ==++++++++++++++++++++++++++++++++++++++++++++==
# ...
#   ===                                      ===
#   ===                                      ===
# 금액 넣기 >> 1500
# 메뉴 선택(번호입력) >> 1
# 1000원 :  0 개 500원 :  1 개 100원 :  4 개
